# %% [markdown]
# ## Count Vector, TFIDF Representations of Text
#
# Working with text generally involves converting it into a format that our model is able to understand, which is mostly numbers. In this notebook, you will have a closer look on two of the most basic and ubiquitiously used formats:
#
#  - Count Vector
#  - TFIDF
#
# You will also build a Machine Learning model on a real world dataset of **BBC News** and perform text classification utilizing the above two formats.
#
# #### Table of Contents
# 1. About the Dataset
# 2. Preprocessing Text
# 3. Working with Count Vector
# 4. Using TFIDF to improve Count Vector
# 5. Conclusion
# 6. Challenge

# %% [markdown]
# ### 1. About the Dataset
#
# The dataset that you are going to use is a collection of news articles from BBC across 5 major categories, namely:
#
#  - Business
#  - Entertainment
#  - Politics
#  - Sport
#  - Tech
#
# There are a total of 2225 articles in the dataset, which is a mix of all of the above categories. Let's load the dataset using pandas and have a quick look at some of the articles.
#
# **Note:** You can get the dataset [here](https://trainings.analyticsvidhya.com/asset-v1:AnalyticsVidhya+LP_DL_2019+2019_T1+type@asset+block@bbc_news_mixed.csv)

# %%
import os
from PyPDF2 import PdfReader
import pandas as pd

# %%
# !pip3 list
# Out:
# Package               Version
# --------------------- -----------
# altair                4.1.0
# appnope               0.1.3
# argon2-cffi           21.3.0
# argon2-cffi-bindings  21.2.0
# async-generator       1.10
# attrs                 22.1.0
# backcall              0.2.0
# backports.zoneinfo    0.2.1
# base58                2.1.1
# bleach                4.1.0
# certifi               2022.5.18.1
# cffi                  1.15.1
# charset-normalizer    2.0.12
# click                 8.0.4
# colorama              0.4.5
# cryptography          38.0.4
# dataclasses           0.8
# decorator             5.1.1
# defusedxml            0.7.1
# easydict              1.9
# entrypoints           0.4
# et-xmlfile            1.1.0
# Flask                 2.0.3
# Flask-Caching         1.10.1
# Flask-Cors            3.0.10
# Flask-Script          2.0.6
# flask-swagger-ui      4.11.1
# great-expectations    0.15.34
# greenlet              1.1.2
# idna                  3.3
# importlib-metadata    4.8.3
# importlib-resources   5.4.0
# ipfshttpclient        0.7.0
# ipykernel             5.5.6
# ipython               7.16.3
# ipython-genutils      0.2.0
# ipywidgets            7.7.2
# itsdangerous          2.0.1
# jedi                  0.17.2
# Jinja2                3.0.3
# joblib                1.1.1
# jsonpatch             1.32
# jsonpointer           2.3
# jsonschema            3.2.0
# jupyter-client        7.1.2
# jupyter-core          4.9.2
# jupyterlab-pygments   0.1.2
# jupyterlab-widgets    1.1.1
# ldap3                 2.9.1
# makefun               1.15.0
# MarkupSafe            2.0.1
# marshmallow           3.14.1
# mistune               0.8.4
# multiaddr             0.0.9
# nbclient              0.5.9
# nbconvert             6.0.7
# nbformat              5.1.3
# nest-asyncio          1.5.6
# netaddr               0.8.0
# notebook              6.4.10
# numpy                 1.19.5
# openpyxl              3.0.10
# packaging             21.3
# pandas                1.1.5
# pandocfilters         1.5.0
# parso                 0.7.1
# pdiclient             0.9
# pexpect               4.8.0
# pickleshare           0.7.5
# pip                   21.3.1
# prometheus-client     0.15.0
# prompt-toolkit        3.0.33
# ptyprocess            0.7.0
# pyasn1                0.4.8
# pycparser             2.21
# pydantic              1.9.2
# Pygments              2.13.0
# pyparsing             3.0.9
# PyPDF2                3.0.1
# pyrsistent            0.18.0
# python-dateutil       2.8.2
# pytz                  2022.1
# pytz-deprecation-shim 0.1.0.post0
# pyzmq                 24.0.1
# requests              2.27.1
# responses             0.17.0
# ruamel.yaml           0.17.17
# ruamel.yaml.clib      0.2.7
# scikit-learn          0.24.2
# scipy                 1.5.4
# Send2Trash            1.8.0
# setuptools            40.6.2
# six                   1.16.0
# sklearn               0.0.post5
# SQLAlchemy            1.4.37
# terminado             0.12.1
# testpath              0.6.0
# threadpoolctl         3.1.0
# toolz                 0.12.0
# tornado               6.1
# tqdm                  4.64.1
# traitlets             4.3.3
# typing_extensions     4.1.1
# tzdata                2022.6
# tzlocal               4.2
# urllib3               1.26.9
# varint                1.0.2
# waitress              2.0.0
# wcwidth               0.2.5
# webencodings          0.5.1
# Werkzeug              2.0.3
# widgetsnbextension    3.6.1
# xlrd                  2.0.1
# XlsxWriter            3.0.3
# zipp                  3.6.0

# %%
# !python3 -m pip install scikit-learn --upgrade
# Out:
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: scipy>=0.19.1 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages (from scikit-learn) (1.1.1)

# %%
def pdf_to_text(pdf_path):
    reader = PdfReader(pdf_path)
 
    # printing number of pages in pdf file
    #print(len(reader.pages))
 
    # getting a specific page from the pdf file
    page = reader.pages[0]
 
    # extracting text from page
    text = page.extract_text()
    #print(text)
    return text

# %%
df = pd.DataFrame(columns = ['text', 'label'])

# %%
mortgage_doc_dir = 'mortgage_documents'
label = 'mortgage'
for filename in os.listdir(mortgage_doc_dir):
    f = os.path.join(mortgage_doc_dir, filename)
    # checking if it is a file
    if os.path.isfile(f):
        #print(f)
        pdf_text = pdf_to_text(f)
        df = df.append({'text' : pdf_text, 'label' : label}, ignore_index = True)

# %%
insurance_doc_dir = 'insurance_documents'
label = 'insurance'
for filename in os.listdir(insurance_doc_dir):
    f = os.path.join(insurance_doc_dir, filename)
    # checking if it is a file
    if os.path.isfile(f):
        #print(f)
        pdf_text = pdf_to_text(f)
        df = df.append({'text' : pdf_text, 'label' : label}, ignore_index = True)

# %%
df.head(12)
# Out:
#                                                  text      label
# 0                                            MORTG...   mortgage
# 1    1 \nDEED OF SIMPLE MORTGAGE  \n \nTHIS DEED O...   mortgage
# 2   Citibank  \nMortgage Loan Agreement\n(Applicab...   mortgage
# 3   LD/2239 \n \n  \nMEMORANDUM OF DEPOSIT OF TITL...   mortgage
# 4    \n \nFORM NO. 3  \n \n \nForm of Mortgage Dee...   mortgage
# 5   MORTGAGE Of Agricultural \nLand With Possessio...   mortgage
# 6   1a. INSURED’S I.D. NUMBER           (FOR PROGR...  insurance
# 7   ITGI / TP / 07 \n \nTRAVEL PROTECTOR INSURANCE...  insurance
# 8     \n 1 \nIFFCO-TOKIO GENERAL INSURANCE COMPANY...  insurance
# 9                             \n   \n 1 \nClaim Fo...  insurance
# 10   \n \n     MOTOR CLAIM FORM      \nIFFCO TOKIO...  insurance
# 11  DIPLOMA IN INSURANCE SERVICES\nMODULE - 3\nNot...  insurance

# %%
# print first 2 articles
for art in df.text[:2]:
    print(art)
# Out:
#  1
# DEED OF SIMPLE MORTGAGE
#
# THIS DEED OF SIMPLE MORTGAGE is made at ______________ this _____
# day of ________ 200__
#  between
#
# (1) _______________, son/daughter of _____________ aged about ______ years
# resident at ___________________(hereinafter referred to as the ‘Mortgagor which
# expression shall unless repugnant to the context or meaning thereof, be deemed
# to mean and include his/her legal heirs, executors and administrators) of the one
# part.
#
# OR (applicable in case of a couple )
#
# _________________, son/daughter of _________________ aged about _____ years
# and his/her spouse __________________, son/daughter of ________________
# aged about _____ years both residing at ___________ (hereinafter referred to as the ‘Mortgagors’  which expression sh all unless repugnant to the context or
# meaning thereof, be deemed to mean and include their legal heirs, executors and
# administrators) of the one part; and
#
# (2) ____________________ [Housing Finance Company (HFC)], a company
# within the meaning of the Companies Act, 1956 (1 of 1956) and having its
# registered office at ________________________ (hereinafter referred to as the
# ‘Mortgagee’ which expression shall, unle ss repugnant to the context or meaning
# thereof, be deemed to include its successors  in interest and assigns) of the other
# part;
#
# OR (in case of a Bank)
#
# [   x   ]    a banking company within the meaning of the Banking Regulation Act,
# 1949 and having its registered /head office at    [  x   ] and a branch office at
# ______________ (hereinafter referred to as the ‘Mortgagee’ which expression
# shall, unless repugnant to the context or  meaning thereof, be deemed to include
# its successors in interest and assigns) of the other part;
#
# WHEREAS:
#
# (A) The Mortgagor is absolutely seized and possessed of or otherwise well
# and sufficiently entitled to the la nd and premises bearing municipal
# survey no. ________ lying being and situate at ___________________ within the city/village limits of [ _____] registration sub-district [_____]
# and district [____] (hereinafter referre d to as the “ Residential Property”)
# more particularly described in the Schedule hereunder written;
#
#
#
# FORM NO. 3
#
#
# Form of Mortgage Deed to be exeucuted when the property is freehold
# [ Rule 5 (a) ]
#
#
# The indenture made this _______________ day of ____________ Two Thousand and
# _________________between _______________son / daughter of _________________ at pr esent
# employed as ____________________ in the Ministry / Office of _________________________ at
# ___________________________ (hereinafter called ‘THE MORTGAGOR’ which expression shall
# unless excluded by or repugnant to the subject or context include his / h er heirs, executors, administrators
# and assigns ) of the ONE PART AND THE PRESIDENT OF INDIA (hereinafter called ‘THE
# MORTGAGOR’ which expression shall unless excluded by or repugnant to the subject or context include
# his successors in office and assigns )  of the OTHER PART.
#
# WHEREAS the Mortgagor is the absolute and sole beneficial owner and is seized and possessed of or
# otherwise well and sufficiently entitled to the land and / or house, hereditaments and premises hereinafter
# described in the Schedule her eunder written and for greater clearness delineated on the plan annexed
# hereto and thereon shown with the boundaries thereof coloured _____________ and expressed to be
# hereby conveyed, transferred and assured (hereinafter referred to as “the said Mortgaged  property”).
#
# AND WHEREAS the MORGAGOR applied to the MORTGAGEE for an advance of
# Rs._______________________  (Rupees _____________________________only) for the purpose of
# enabling the  MORTGAGOR -
#  1(1) to purchase land and to construct a house thereon or * (to enlarge living accommodation in the
# existing house on the said hereditaments).
#  1(2) to construct a house on the said hereditaments, or * (to enlarge living accommodation in the house on
# the said hereditaments).
#  1(3) to purchase a ready -built afores aid house.
#
# AND WHEREAS the Mortgagee agreed to advance to the Morgagor the said sum of
# Rs.____________________(Rupees ____________________) (insert full amount), vide the Ministry /
# Office Letter No._____________ dated ___________, a copy of which is anne xed to these presents for
# the purpose aforesaid on the terms and conditions set forth therein, etc.
#
# AND WHEREAS one of the conditions for the aforesaid advance is that the Mortgagor should secure the
# repayment of the said advance and on observance of all the terms and conditions contained in the “Rules
# to regulate the grant of advances to Central Government servants for building etc., of houses” issued by
# the Government of India, Ministry of Works, Housing and Supply with their O.M. No.H II -27(5)/54,
# dated  the 12th April, 1956 (hereinafter referred to as the “said Rules” which expression shall, where the
# context so admits include any amendment thereof or addition thereto for the time being in force) by a
# Mortgage of the property described in the schedule he reunder written.
# ______________________________________________________________________  1mention whatever is applicable.

# %% [markdown]
# Now that you have an idea of how your data looks like, let's see the count of each category in the dataset!

# %%
# category-wise count
df.label.value_counts()
# Out:
# insurance    6
# mortgage     6
# Name: label, dtype: int64

# %% [markdown]
# ### 2. Preprocessing Text
#
# You would have noticed that the labels are in text format, in order to build a model on this dataset you will have to create a mapping between the labels and numbers like 0,1,2,3 this process is called Label Encoding. You can easily label encode your text data using sklearn's [LabelEncoder](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.LabelEncoder.html). Let's have a look at how to do that!

# %%
from sklearn.preprocessing import LabelEncoder

# initialize LabelEncoder
lencod = LabelEncoder()
# fit_transform() converts the text to numbers
df.label = lencod.fit_transform(df.label)
# label-wise count
df.label.value_counts()
# Out:
# 1    6
# 0    6
# Name: label, dtype: int64

# %%
df.label
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
# 5     1
# 6     0
# 7     0
# 8     0
# 9     0
# 10    0
# 11    0
# Name: label, dtype: int64

# %% [markdown]
# **Note** You'd have noticed in the output of the above code that the text labels have been replaced by numbers. We have a mapping like this -
#  - 0 is Business
#  - 1 is Entertainment
#  - 2 is Politics
#  - 3 is Sport
#  - 4 is Tech
#
#  ## 0 -> insurance ; 1 -> mortgage
#
# ### 3. Working with Count Vector
#
# Sklearn provides an easy way to create count vectors from a piece of text. You can use the [CountVectorizer](https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html) to do that. Let's see how simple it is!

# %%
from sklearn.feature_extraction.text import CountVectorizer

# initialize count vector
cvec = CountVectorizer(stop_words='english')
# create Bag of Words
bow = cvec.fit_transform(df.text)
# shape of Bag of Words
print('shape of BOW:', bow.shape)
# number of words in the vocabulary
print('No. of words in vocabulary:', len(cvec.vocabulary_))
# Out:
# shape of BOW: (12, 906)
# No. of words in vocabulary: 906

# %% [markdown]
# Let's have a closer look at the Bag of Words that you have just generated.

# %% [markdown]
# If you explore the above dataframe, you will find that the Bag of Words representation of the text. Notice that the word "called" appears in the first only once hence there is a 1 at it's index. Now that your BOW is created, let's see just how good is it at classifying the articles in a ML model.
#
# You'll be using [MultinomialNB](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html) model because it works well with sparse features of text.

# %%
df.head()
# Out:
#                                                 text  label
# 0   1 \nDEED OF SIMPLE MORTGAGE  \n \nTHIS DEED O...      1
# 1   \n \nFORM NO. 3  \n \n \nForm of Mortgage Dee...      1
# 2  LD/2239 \n \n  \nMEMORANDUM OF DEPOSIT OF TITL...      1
# 3  Citibank  \nMortgage Loan Agreement\n(Applicab...      1
# 4  MORTGAGE Of Agricultural \nLand With Possessio...      1

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB

# creates a ML model based on parameters
def create_model(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
    model = MultinomialNB()
    model = model.fit(X_train, y_train)
    return model, X_test, y_test

# %%
# create BOW based classification model
model_b, X_test_b, y_test_b = create_model(bow, df.label)

# %% [markdown]
# Now that the model is created and trained, have a look at the classification accuracy:

# %%
from sklearn.metrics import accuracy_score

# check accuracy 
accuracy_score(y_test_b, model_b.predict(X_test_b))
# Out:
# 0.75

# %%
type(X_test_b)
# Out:
# scipy.sparse.csr.csr_matrix

# %%
test_df = pd.DataFrame(["This is a insurance document"], columns=['text'])

# %%
test_df.head()
# Out:
#                            text
# 0  This is a insurance document

# %%
# create Bag of Words
bow_test = cvec.transform(test_df.text)

# %%
# bow_test.shape
bow_test
# Out:
# <1x906 sparse matrix of type '<class 'numpy.int64'>'
# 	with 2 stored elements in Compressed Sparse Row format>

# %%
model_b.predict(bow_test)
# Out:
# array([0])

# %%
import joblib

# %%
filename = 'model.sav'
joblib.dump(model_b, filename)

filename = 'countvectorizer.sav'
joblib.dump(cvec, filename)
# Out:
# ['countvectorizer.sav']

# %%
import joblib
loaded_model = joblib.load("model.sav")
loaded_cvec = joblib.load("countvectorizer.sav")

# %%
test_df1 = pd.DataFrame(["This is a MORTGAGE document"], columns=['text'])

# %%
bow_test1 = loaded_cvec.transform(test_df1.text)

# %%
bow_test2 = loaded_cvec.transform(test_df.text)

# %%
loaded_model.predict(bow_test1)
# Out:
# array([1])

# %%
loaded_model.predict(bow_test2)
# Out:
# 0

# %%
cvec.vocabulary_
# Out:
# {'deed': 291,
#  'simple': 762,
#  'mortgage': 557,
#  '______________': 58,
#  '_____': 49,
#  'day': 287,
#  '________': 52,
#  '200__': 26,
#  '_______________': 59,
#  'son': 769,
#  'daughter': 286,
#  '_____________': 57,
#  'aged': 126,
#  '______': 50,
#  'years': 896,
#  'resident': 706,
#  '___________________': 63,
#  'hereinafter': 416,
#  'referred': 678,
#  'mortgagor': 561,
#  'expression': 359,
#  'shall': 750,
#  'unless': 861,
#  'repugnant': 701,
#  'context': 256,
#  'meaning': 531,
#  'thereof': 823,
#  'deemed': 293,
#  'mean': 530,
#  'include': 444,
#  'legal': 495,
#  'heirs': 414,
#  'executors': 352,
#  'administrators': 117,
#  'applicable': 142,
#  'case': 205,
#  'couple': 269,
#  '_________________': 61,
#  'spouse': 776,
#  '__________________': 62,
#  '________________': 60,
#  'residing': 708,
#  '___________': 55,
#  'mortgagors': 562,
#  'sh': 749,
#  '____________________': 64,
#  'housing': 428,
#  'finance': 378,
#  'company': 241,
#  'hfc': 419,
#  'companies': 240,
#  'act': 112,
#  '1956': 22,
#  'having': 408,
#  'registered': 681,
#  'office': 593,
#  '________________________': 68,
#  'mortgagee': 559,
#  'unle': 860,
#  'ss': 779,
#  'successors': 797,
#  'assigns': 153,
#  'bank': 167,
#  'banking': 168,
#  'regulation': 685,
#  '1949': 21,
#  'head': 411,
#  'branch': 192,
#  'absolutely': 104,
#  'seized': 737,
#  'possessed': 641,
#  'sufficiently': 798,
#  'entitled': 338,
#  'la': 487,
#  'nd': 573,
#  'premises': 647,
#  'bearing': 170,
#  'municipal': 566,
#  'survey': 805,
#  'lying': 521,
#  'situate': 764,
#  'city': 221,
#  'village': 877,
#  'limits': 507,
#  'registration': 683,
#  'sub': 792,
#  'district': 311,
#  '____': 48,
#  'referre': 677,
#  'residential': 707,
#  'property': 664,
#  'particularly': 613,
#  'described': 301,
#  'schedule': 728,
#  'hereunder': 418,
#  'written': 893,
#  'form': 386,
#  'exeucuted': 353,
#  'freehold': 391,
#  'rule': 720,
#  'indenture': 447,
#  '____________': 56,
#  'thousand': 829,
#  '_________________between': 88,
#  '_______________son': 89,
#  'pr': 644,
#  'esent': 343,
#  'employed': 327,
#  'ministry': 544,
#  '_________________________': 69,
#  '___________________________': 70,
#  'called': 199,
#  'excluded': 348,
#  'subject': 793,
#  'er': 342,
#  'president': 651,
#  'india': 448,
#  'absolute': 103,
#  'sole': 768,
#  'beneficial': 174,
#  'owner': 605,
#  'land': 490,
#  'house': 426,
#  'hereditaments': 415,
#  'eunder': 345,
#  'greater': 403,
#  'clearness': 230,
#  'delineated': 297,
#  'plan': 635,
#  'annexed': 141,
#  'hereto': 417,
#  'thereon': 824,
#  'shown': 753,
#  'boundaries': 190,
#  'coloured': 235,
#  'expressed': 358,
#  'conveyed': 261,
#  'transferred': 841,
#  'assured': 156,
#  'said': 725,
#  'mortgaged': 558,
#  'morgagor': 554,
#  'applied': 143,
#  'advance': 121,
#  'rs': 719,
#  '_______________________': 67,
#  'rupees': 722,
#  '_____________________________only': 87,
#  'purpose': 669,
#  'enabling': 330,
#  'purchase': 668,
#  'construct': 251,
#  'enlarge': 336,
#  'living': 512,
#  'accommodation': 108,
#  'existing': 355,
#  'ready': 674,
#  'built': 196,
#  'afores': 124,
#  'aid': 131,
#  'agreed': 127,
#  'sum': 800,
#  'insert': 457,
#  'vide': 875,
#  'letter': 501,
#  'dated': 284,
#  'copy': 262,
#  'anne': 140,
#  'xed': 894,
#  'presents': 650,
#  'aforesaid': 125,
#  'terms': 814,
#  'conditions': 247,
#  'set': 747,
#  'forth': 389,
#  'secure': 734,
#  'repayment': 695,
#  'observance': 588,
#  'contained': 255,
#  'rules': 721,
#  'regulate': 684,
#  'grant': 402,
#  'advances': 123,
#  'central': 207,
#  'government': 400,
#  'servants': 742,
#  'building': 195,
#  'houses': 427,
#  'issued': 476,
#  'works': 891,
#  'supply': 803,
#  'ii': 435,
#  '27': 36,
#  '54': 43,
#  '12th': 10,
#  'april': 146,
#  'admits': 120,
#  'amendment': 137,
#  'addition': 115,
#  'thereto': 825,
#  'time': 832,
#  'force': 385,
#  'reunder': 713,
#  '______________________________________________________________________': 85,
#  '1mention': 24,
#  'ld': 492,
#  '2239': 30,
#  'memorandum': 539,
#  'deposit': 299,
#  'title': 833,
#  'deeds': 292,
#  'executed': 349,
#  '_________': 53,
#  '20by': 29,
#  '_________________________________': 75,
#  'representatives': 700,
#  'favour': 368,
#  'south': 771,
#  'indian': 449,
#  'thrissur': 830,
#  '680': 44,
#  '001': 1,
#  'kerala': 482,
#  'places': 634,
#  'assings': 154,
#  'respect': 709,
#  'entioned': 337,
#  'create': 275,
#  'security': 736,
#  'loan': 514,
#  'borrowed': 188,
#  'deposited': 300,
#  'following': 384,
#  'documents': 318,
#  'relating': 688,
#  'properties': 663,
#  'listed': 511,
#  'ir': 473,
#  'intent': 465,
#  'equitable': 341,
#  'ies': 433,
#  'document': 314,
#  'relate': 686,
#  'securing': 735,
#  'amounts': 138,
#  'owing': 604,
#  'mort': 555,
#  'gagee': 392,
#  'concern': 244,
#  'partner': 615,
#  'proprietor': 665,
#  'way': 880,
#  '_______': 51,
#  'interests': 467,
#  'charges': 215,
#  'declare': 290,
#  'possession': 642,
#  'control': 259,
#  'charged': 214,
#  'encumbered': 331,
#  'whatsoever': 883,
#  'list': 510,
#  'docum': 313,
#  'ents': 340,
#  'sl': 766,
#  'number': 582,
#  'date': 282,
#  'parties': 614,
#  'nature': 571,
#  'description': 302,
#  'piece': 631,
#  'parcel': 611,
#  'measuring': 533,
#  '_____________________': 65,
#  '__': 47,
#  'panchayat': 609,
#  'municipality': 567,
#  'corporation': 264,
#  '__________': 54,
#  'taluk': 808,
#  'bounded': 191,
#  'east': 321,
#  'west': 882,
#  'north': 578,
#  'situated': 765,
#  'witness': 887,
#  'whereof': 884,
#  'subscribed': 794,
#  'signatures': 756,
#  'month': 552,
#  'year': 895,
#  'mentioned': 541,
#  'citibank': 220,
#  'agreement': 128,
#  'variable': 870,
#  'rate': 672,
#  'loans': 515,
#  'indians': 450,
#  'treasury': 847,
#  'benchmark': 173,
#  'linked': 509,
#  'lending': 498,
#  'tblr': 811,
#  'borrower': 189,
#  '______________________________________': 77,
#  'agricultural': 129,
#  'know': 485,
#  'men': 540,
#  '________________________________________________': 79,
#  '_________________________________________________': 80,
#  '___________________________________________________': 81,
#  'agriculture': 130,
#  'measuring____acre______kanal_______marla______': 534,
#  '___share': 98,
#  'hadbast': 406,
#  '_______khewat': 94,
#  '_______khatoni': 93,
#  '___k': 97,
#  'hasra': 407,
#  '___________mustil': 91,
#  '______kilano____________________________________': 96,
#  'city______________tehsil__________district_': 222,
#  '__________by': 92,
#  'mutation': 568,
#  '______________jamabandi__________year': 90,
#  'sale': 727,
#  'fice': 373,
#  'registrar_________________': 682,
#  'mortgages': 560,
#  'abov': 102,
#  'witnesseth': 888,
#  'lieu': 504,
#  'gives': 397,
#  'iod': 472,
#  'transfers': 842,
#  'limited': 506,
#  'ownership': 606,
#  'propert': 662,
#  'format': 387,
#  '201x': 27,
#  'hindu': 421,
#  'favor': 367,
#  'thiru': 827,
#  'term': 813,
#  'representa': 699,
#  'tives': 834,
#  'trustees': 852,
#  'immovable': 438,
#  'morefully': 553,
#  'cal': 198,
#  'led': 494,
#  'scheduled': 729,
#  'acquired': 111,
#  'enjoyment': 335,
#  'paying': 621,
#  'taxes': 810,
#  'levies': 502,
#  'need': 575,
#  'money': 551,
#  'family': 365,
#  'expenses': 356,
#  'requested': 703,
#  'lend': 497,
#  'executing': 350,
#  'present': 649,
#  'view': 876,
#  'provided': 667,
#  'pursuant': 670,
#  'consideration': 249,
#  'lent': 499,
#  'advanced': 122,
#  'execution': 351,
#  'receipt': 675,
#  'admit': 119,
#  'covenants': 271,
#  'pay': 620,
#  'subsequent': 795,
#  'installment': 458,
#  'succeeding': 796,
#  'principle': 653,
#  'claim': 223,
#  'forms': 388,
#  'iffco': 434,
#  'tokio': 835,
#  'general': 395,
#  'insurance': 461,
#  'sadan': 723,
#  'centre': 208,
#  'saket': 726,
#  'new': 576,
#  'delhi': 296,
#  '110017': 8,
#  'issue': 475,
#  'note': 579,
#  'prejudice': 646,
#  'policy': 640,
#  'issuance': 474,
#  'construed': 252,
#  'admission': 118,
#  'liability': 503,
#  'blanks': 184,
#  'complete': 242,
#  'details': 303,
#  'information': 452,
#  'asked': 151,
#  'space': 772,
#  'insufficient': 460,
#  'separate': 740,
#  'sheet': 751,
#  'kindly': 483,
#  'return': 712,
#  'duly': 319,
#  'filled': 376,
#  'signed': 757,
#  '15': 12,
#  'days': 288,
#  'occurrence': 592,
#  'loss': 519,
#  'location': 517,
#  'address': 116,
#  'circumstances': 219,
#  'brief': 193,
#  'write': 892,
#  'took': 838,
#  'place': 633,
#  'spread': 777,
#  'fighting': 374,
#  'efforts': 322,
#  'finally': 377,
#  'controlled': 260,
#  'opinion': 596,
#  'cause': 206,
#  'estimate': 344,
#  'sr': 778,
#  'block': 186,
#  'stocks': 788,
#  'packing': 607,
#  'material': 529,
#  'insurances': 462,
#  'insured': 463,
#  'undersigned': 857,
#  'confirm': 248,
#  'given': 396,
#  'ar': 147,
#  'true': 851,
#  'correct': 265,
#  'best': 177,
#  'knowledge': 486,
#  '1a': 23,
#  'program': 659,
#  'item': 478,
#  'middle': 542,
#  'initial': 454,
#  'street': 789,
#  'statezip': 785,
#  'code': 233,
#  'telephone': 812,
#  'area': 148,
#  '11': 7,
#  'group': 404,
#  'feca': 369,
#  'numbera': 583,
#  'birthb': 182,
#  'employer': 328,
#  'school': 730,
#  'namec': 569,
#  'named': 570,
#  'health': 413,
#  'benefit': 175,
#  '13': 11,
#  'authorized': 162,
#  'person': 625,
#  'signature': 755,
#  'authorize': 161,
#  'payment': 622,
#  'medical': 537,
#  'benefits': 176,
#  'physician': 629,
#  'supplier': 801,
#  'services': 746,
#  'sex': 748,
#  'fhealth': 372,
#  'medicare': 538,
#  'medicaid': 536,
#  'champus': 211,
#  'champva': 212,
#  'read': 673,
#  'completing': 243,
#  'signing': 759,
#  '12': 9,
#  'patient': 619,
#  'release': 690,
#  'necessary': 574,
#  'process': 657,
#  'request': 702,
#  'party': 617,
#  'accepts': 106,
#  'assignment': 152,
#  'illness': 436,
#  'symptom': 806,
#  'injury': 455,
#  'accident': 107,
#  'orpregnancy': 599,
#  'lmp': 513,
#  'mm': 545,
#  'dd': 289,
#  'yy15': 900,
#  'similar': 761,
#  'yy14': 899,
#  'current': 278,
#  '17': 16,
#  'referring': 679,
#  'source': 770,
#  '19': 20,
#  'reserved': 705,
#  'local': 516,
#  'use21': 864,
#  'diagnosis': 305,
#  'items': 479,
#  '24e': 33,
#  'line': 508,
#  '17a': 17,
#  'yyto': 901,
#  'yy': 898,
#  '23456': 31,
#  '25': 34,
#  'federal': 370,
#  'tax': 809,
#  'ssn': 780,
#  'ein': 323,
#  '26': 35,
#  'account': 110,
#  'accept': 105,
#  'govt': 401,
#  'claims': 227,
#  '31': 40,
#  'including': 445,
#  'degrees': 294,
#  'credentials': 276,
#  'certify': 210,
#  'statements': 784,
#  'reverse': 714,
#  'apply': 144,
#  'date32': 283,
#  'facility': 362,
#  'rendered': 693,
#  'home': 423,
#  'signedmm': 758,
#  'tomm': 837,
#  'original': 598,
#  'ref': 676,
#  'emg': 326,
#  'cobreserved': 232,
#  'use': 863,
#  '28': 37,
#  'total': 839,
#  'charge': 213,
#  '29': 38,
#  'paid': 608,
#  '30': 39,
#  'balance': 166,
#  '33': 41,
#  'billing': 180,
#  'zip': 903,
#  'phone': 628,
#  'pin': 632,
#  'grp': 405,
#  'pica': 630,
#  'numberb': 584,
#  'birthc': 183,
#  'approved': 145,
#  'ama': 136,
#  'council': 268,
#  'service': 743,
#  '88': 45,
#  'yes': 897,
#  '16': 15,
#  'dates': 285,
#  'unable': 855,
#  'work': 890,
#  'occupation': 590,
#  '18': 18,
#  'hospitalization': 425,
#  'related': 687,
#  '20': 25,
#  'outside': 602,
#  'lab': 488,
#  'charges22': 216,
#  'resubmission23': 711,
#  'prior': 655,
#  'authorization': 160,
#  'numbermm': 585,
#  'carrier': 203,
#  'informationm': 453,
#  'type': 854,
#  'serviceplace': 744,
#  'serviceprocedures': 745,
#  'supplies': 802,
#  'explain': 357,
#  'unusual': 862,
#  'cpt': 274,
#  'hcpcs': 410,
#  'modifierdiagnosis': 548,
#  'codeplease': 234,
#  'notstaplein': 581,
#  'thisarea': 828,
#  'msexmm': 565,
#  'noplace': 577,
#  'state': 783,
#  'planfeca': 636,
#  'blk': 185,
#  'lung': 520,
#  'single': 763,
#  'married': 528,
#  'other3': 600,
#  'birth': 181,
#  'relationship': 689,
#  'insured8': 464,
#  'status': 787,
#  '10': 4,
#  'condition': 246,
#  'employment': 329,
#  'previous': 652,
#  'auto': 163,
#  '10d': 6,
#  'useemployed': 866,
#  'student': 790,
#  'studentself': 791,
#  'child': 218,
#  'sponsor': 775,
#  'va': 868,
#  'file': 375,
#  'id': 431,
#  'sn': 767,
#  'msex': 564,
#  'unitsepsdt': 859,
#  'planfg': 637,
#  '24': 32,
#  'print': 654,
#  'hcfa': 409,
#  '1500': 13,
#  '90': 46,
#  'rrb': 718,
#  'owcp': 603,
#  '1500approved': 14,
#  'omb': 595,
#  '0938': 3,
#  '0008': 0,
#  'diploma': 307,
#  'module': 549,
#  'notesinsurance': 580,
#  'practice': 645,
#  'life': 505,
#  '202': 28,
#  'introduction': 470,
#  'evidence': 346,
#  'existence': 354,
#  'contract': 257,
#  'vogue': 878,
#  'stand': 781,
#  'proof': 660,
#  'theinsurer': 821,
#  'major': 522,
#  'inlife': 456,
#  'premium': 648,
#  'endorsements': 333,
#  'objectiveafter': 586,
#  'going': 398,
#  'lesson': 500,
#  'able': 101,
#  'zrecall': 905,
#  'various': 871,
#  'used': 865,
#  'zlearn': 904,
#  'utility': 867,
#  'documentationlife': 315,
#  'legally': 496,
#  'enforceable': 334,
#  'qualified': 671,
#  'istherefore': 477,
#  'theagreement': 819,
#  'suitably': 799,
#  'documented': 316,
#  'manner': 526,
#  'thatwould': 818,
#  'make': 523,
#  'clear': 228,
#  'ad': 114,
#  'idem': 432,
#  'mind': 543,
#  'means': 532,
#  'theparties': 822,
#  'understand': 858,
#  'thing': 826,
#  'sense': 739,
#  'areof': 149,
#  'beconsensus': 171,
#  'possible': 643,
#  'rights': 715,
#  'duties': 320,
#  'privileges': 656,
#  'obligations': 587,
#  'properly': 661,
#  'documentedin': 317,
#  'clearly': 229,
#  'interpreted': 468,
#  'court': 270,
#  'law': 491,
#  'human': 430,
#  'beings': 172,
#  'silence': 760,
#  'an2': 139,
#  'marine': 527,
#  'wi': 886,
#  'th': 817,
#  'cover': 272,
#  'certificate': 209,
#  'interested': 466,
#  'detected': 304,
#  'damage': 280,
#  'carriers': 204,
#  'obtained': 589,
#  'monetary': 550,
#  'lodged': 518,
#  'voyage': 879,
#  'journey': 481,
#  'vered': 874,
#  'goods': 399,
#  'transit': 843,
#  'mode': 547,
#  'transportation': 844,
#  'extent': 360,
#  'invoice': 471,
#  'lading': 489,
#  'airway': 134,
#  'entry': 339,
#  'consignment': 250,
#  'report': 696,
#  'basis': 169,
#  'valuation': 869,
#  'claimed': 225,
#  'motor': 563,
#  'regd': 680,
#  'intimate': 469,
#  'toll': 836,
#  'free': 390,
#  '1800': 19,
#  '1035': 5,
#  '499': 42,
#  'important': 439,
#  'instructions': 459,
#  'taken': 807,
#  'vehicle': 873,
#  'partnership': 616,
#  'corporate': 263,
#  'body': 187,
#  'signatory': 754,
#  'seal': 731,
#  'concerne': 245,
#  'organization': 597,
#  'leave': 493,
#  'column': 236,
#  'unanswered': 856,
#  'facts': 363,
#  'factual': 364,
#  'influenced': 451,
#  'biased': 178,
#  'damaged': 281,
#  'parked': 612,
#  'safe': 724,
#  'avoid': 164,
#  'responsible': 710,
#  'carefully': 201,
#  'attached': 158,
#  'required': 704,
#  'faster': 366,
#  'processing': 658,
#  'self': 738,
#  'attested': 159,
#  'holder': 422,
#  '______claim': 95,
#  'period': 624,
#  '__to': 99,
#  '______________________': 66,
#  '________________________________': 74,
#  'mobile': 546,
#  '_____________________________________________________________________': 84,
#  '______________________________________________________________________________': 86,
#  '______________________________________________________': 82,
#  'email': 324,
#  'gender': 394,
#  'male': 524,
#  'female': 371,
#  'yyyy': 902,
#  'inciden': 440,
#  'theft': 820,
#  '_time': 100,
#  'speed': 774,
#  'km': 484,
#  'hr': 429,
#  'exact': 347,
#  'incident': 441,
#  'occurred': 591,
#  '____________________________________________________________': 83,
#  'heading': 412,
#  '_____________________________': 72,
#  'fo': 382,
#  'weight': 881,
#  'carried': 202,
#  'comm': 237,
#  'veh': 872,
#  'people': 623,
#  'travelling': 846,
#  'ime': 437,
#  'reported': 697,
#  'police': 639,
#  'olice': 594,
#  'station': 786,
#  '_______________________________________________': 78,
#  'gen': 393,
#  'diary': 306,
#  'crime': 277,
#  'fir': 380,
#  '____________________________': 71,
#  '__________________________________': 76,
#  '______________________________': 73,
#  'itgi': 480,
#  'tp': 840,
#  '07': 2,
#  'travel': 845,
#  'protector': 666,
#  'plans': 638,
#  'relevant': 691,
#  'sections': 733,
#  'attach': 157,
#  'sheets': 752,
#  'claimant': 224,
#  'trip': 850,
#  'commenced': 238,
#  'section': 732,
#  'pertains': 627,
#  'tick': 831,
#  'whichever': 885,
#  'incl': 443,
#  'dental': 298,
#  'treatment': 849,
#  'hospital': 424,
#  'daily': 279,
#  'allowance': 135,
#  'hijack': 420,
#  'distress': 310,
#  'passport': 618,
#  'baggage': 165,
#  'checked': 217,
#  'delay': 295,
#  'financial': 379,
#  'emergency': 325,
#  'assistance': 155,
#  'personal': 626,
#  'supported': 804,
#  'costs': 267,
#  'incurred': 446,
#  'doctor': 312,
#  'test': 815,
#  'reports': 698,
#  'papers': 610,
#  'discharge': 308,
#  'card': 200,
#  'treating': 848,
#  'clinic': 231,
#  'disease': 309,
#  'contracted': 258,
#  'manifested': 525,
#  'started': 782,
#  'contact': 254,
#  'ended': 332,
#  'briefly': 194,
#  'separately': 741,
#  'room': 716,
#  'rent': 694,
#  'words': 889,
#  'consultancy': 253,
#  'cost': 266,
#  'tests': 816,
#  'outpatient': 601,
#  'claiming': 226,
#  'extra': 361,
#  'accompanying': 109,
#  'mortal': 556,
#  'remains': 692,
#  'burial': 197,
#  'specify': 773,
#  'airlines': 133,
#  'ncurred': 572,
#  'incidental': 442,
#  'bifurcation': 179,
#  'media': 535,
#  'tv': 853,
#  'coverage': 273,
#  'arrival': 150,
#  'airline': 132,
#  'commencement': 239,
#  'flight': 381,
#  'route': 717,
#  'followed': 383,
#  'actual': 113}

# %% [markdown]
# ### 5. Conclusion
#
#  - Notice that using TFIDF word presentation, you were able to build a better model by just using 4000 words as oppossed to the 29,192 words of the BOW.
#  - This is where TFIDF's strength lies which gives the intution that rest of the 25,000+ words weren't adding much useful information to the model and would be common among many documents.
#  - You can know more about the word vectors, TFIDF and similar text embeddings in [this comprehensive article](https://www.analyticsvidhya.com/blog/2017/06/word-embeddings-count-word2veec/).
#  - Finally, note that you could have gotten an even better accuracy by doing preprocessing over the text like Normalization, spelling correction and much more.

# %% [markdown]
# ### 6. Challenge
#
# If you notice the TFIDF dataframe, words like `demand` `demands` and `demanded` are counted separately this is because the data set isn't normalize yet. I encourage you to go ahead and try to do that using concepts learnt in the previous classes.

# %%
# Your code here
